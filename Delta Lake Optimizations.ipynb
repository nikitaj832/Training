# %% [markdown]
# ## **Create a Delta table and demonstrate ACID transactions.**

# %% [markdown]
# **What Are ACID Transactions?**
#
# Delta Lake ensures Atomicity, Consistency, Isolation, and Durability for all operations like INSERT, UPDATE, DELETE, and MERGE, even in a distributed environment.

# %%
# %sql

CREATE TABLE IF NOT EXISTS sales (
  sale_id      INT,
  product      STRING,
  quantity     INT,
  sale_date    DATE
)
USING DELTA;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql

INSERT INTO sales VALUES
(1, 'Laptop', 2, '2024-01-01'),
(2, 'Mouse', 5, '2024-01-02'),
(3, 'Keyboard', 3, '2024-01-03');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
UPDATE sales
SET quantity = 10
WHERE product = 'Mouse';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
# %sql
DELETE FROM sales
WHERE product = 'Keyboard';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
# %sql
MERGE INTO sales AS target
USING (SELECT 2 AS sale_id, 'Mouse' AS product, 7 AS quantity, '2024-01-02' AS sale_date) AS source
ON target.sale_id = source.sale_id
WHEN MATCHED THEN UPDATE SET quantity = source.quantity
WHEN NOT MATCHED THEN INSERT *;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sale_id</th><th>product</th><th>quantity</th><th>sale_date</th></tr></thead><tbody><tr><td>1</td><td>Laptop</td><td>2</td><td>2024-01-01</td></tr><tr><td>2</td><td>Mouse</td><td>7</td><td>2024-01-02</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE HISTORY sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>6</td><td>2025-06-12T07:56:40.000+0000</td><td>3303542899615855</td><td>21embit039@mlvti.ac.in</td><td>MERGE</td><td>Map(predicate -> ["(sale_id#5014 = sale_id#5006)"], matchedPredicates -> [{"actionType":"update"}], notMatchedPredicates -> [{"actionType":"insert"}], notMatchedBySourcePredicates -> [])</td><td>null</td><td>List(2607602309278239)</td><td>0612-074411-zrk0t7cm</td><td>5</td><td>WriteSerializable</td><td>false</td><td>Map(numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 1, numTargetBytesAdded -> 1318, numTargetBytesRemoved -> 1318, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 1, executionTimeMs -> 4448, materializeSourceTimeMs -> 198, numTargetRowsInserted -> 0, numTargetRowsMatchedDeleted -> 0, scanTimeMs -> 2108, numTargetRowsUpdated -> 1, numOutputRows -> 1, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 1, numTargetFilesRemoved -> 1, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 1925)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>5</td><td>2025-06-12T07:56:02.000+0000</td><td>3303542899615855</td><td>21embit039@mlvti.ac.in</td><td>UPDATE</td><td>Map(predicate -> ["(product#4484 = Mouse)"])</td><td>null</td><td>List(2607602309278239)</td><td>0612-074411-zrk0t7cm</td><td>4</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 1, numRemovedBytes -> 1318, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 2014, scanTimeMs -> 835, numAddedFiles -> 1, numUpdatedRows -> 1, numAddedBytes -> 1318, rewriteTimeMs -> 1177)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>4</td><td>2025-06-12T07:53:00.000+0000</td><td>3303542899615855</td><td>21embit039@mlvti.ac.in</td><td>MERGE</td><td>Map(predicate -> ["(sale_id#2453 = sale_id#2445)"], matchedPredicates -> [{"actionType":"update"}], notMatchedPredicates -> [{"actionType":"insert"}], notMatchedBySourcePredicates -> [])</td><td>null</td><td>List(2607602309278239)</td><td>0612-074411-zrk0t7cm</td><td>3</td><td>WriteSerializable</td><td>false</td><td>Map(numTargetRowsCopied -> 1, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 2, numTargetBytesAdded -> 2643, numTargetBytesRemoved -> 1328, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 1, executionTimeMs -> 8353, materializeSourceTimeMs -> 485, numTargetRowsInserted -> 0, numTargetRowsMatchedDeleted -> 0, scanTimeMs -> 3567, numTargetRowsUpdated -> 1, numOutputRows -> 2, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 1, numTargetFilesRemoved -> 1, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 3714)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>3</td><td>2025-06-12T07:52:27.000+0000</td><td>3303542899615855</td><td>21embit039@mlvti.ac.in</td><td>DELETE</td><td>Map(predicate -> ["(product#1837 = Keyboard)"])</td><td>null</td><td>List(2607602309278239)</td><td>0612-074411-zrk0t7cm</td><td>2</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 1, numRemovedBytes -> 1356, numCopiedRows -> 2, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 3324, numDeletedRows -> 1, scanTimeMs -> 2017, numAddedFiles -> 1, numAddedBytes -> 1328, rewriteTimeMs -> 1306)</td><td>null</td><td>Databricks-Runtime/12.2 ...

# %%
# %sql
SELECT * FROM sales VERSION AS OF 0;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sale_id</th><th>product</th><th>quantity</th><th>sale_date</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## **Use time travel to query a previous version of data.**

# %%
# %sql
DESCRIBE HISTORY sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>7</td><td>2025-06-12T07:57:07.000+0000</td><td>3303542899615855</td><td>21embit039@mlvti.ac.in</td><td>MERGE</td><td>Map(predicate -> ["(sale_id#6305 = sale_id#6297)"], matchedPredicates -> [{"actionType":"update"}], notMatchedPredicates -> [{"actionType":"insert"}], notMatchedBySourcePredicates -> [])</td><td>null</td><td>List(2607602309278239)</td><td>0612-074411-zrk0t7cm</td><td>6</td><td>WriteSerializable</td><td>false</td><td>Map(numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 1, numTargetBytesAdded -> 1318, numTargetBytesRemoved -> 1318, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 1, executionTimeMs -> 3721, materializeSourceTimeMs -> 115, numTargetRowsInserted -> 0, numTargetRowsMatchedDeleted -> 0, scanTimeMs -> 1491, numTargetRowsUpdated -> 1, numOutputRows -> 1, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 1, numTargetFilesRemoved -> 1, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 1925)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>6</td><td>2025-06-12T07:56:40.000+0000</td><td>3303542899615855</td><td>21embit039@mlvti.ac.in</td><td>MERGE</td><td>Map(predicate -> ["(sale_id#5014 = sale_id#5006)"], matchedPredicates -> [{"actionType":"update"}], notMatchedPredicates -> [{"actionType":"insert"}], notMatchedBySourcePredicates -> [])</td><td>null</td><td>List(2607602309278239)</td><td>0612-074411-zrk0t7cm</td><td>5</td><td>WriteSerializable</td><td>false</td><td>Map(numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 1, numTargetBytesAdded -> 1318, numTargetBytesRemoved -> 1318, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 1, executionTimeMs -> 4448, materializeSourceTimeMs -> 198, numTargetRowsInserted -> 0, numTargetRowsMatchedDeleted -> 0, scanTimeMs -> 2108, numTargetRowsUpdated -> 1, numOutputRows -> 1, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 1, numTargetFilesRemoved -> 1, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 1925)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>5</td><td>2025-06-12T07:56:02.000+0000</td><td>3303542899615855</td><td>21embit039@mlvti.ac.in</td><td>UPDATE</td><td>Map(predicate -> ["(product#4484 = Mouse)"])</td><td>null</td><td>List(2607602309278239)</td><td>0612-074411-zrk0t7cm</td><td>4</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 1, numRemovedBytes -> 1318, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 2014, scanTimeMs -> 835, numAddedFiles -> 1, numUpdatedRows -> 1, numAddedBytes -> 1318, rewriteTimeMs -> 1177)</td><td>null</td><td>Databricks-Runtime/12.2.x-scala2.12</td></tr><tr><td>4</td><td>2025-06-12T07:53:00.000+0000</td><td>3303542899615855</td><td>21embit039@mlvti.ac.in</td><td>MERGE</td><td>Map(predicate -> ["(sale_id#2453 = sale_id#2445)"], matchedPredicates -> [{"actionType":"update"}], notMatchedPredicates -> [{"actionType":"insert"}], notMatchedBySourcePredicates -> [])</td><td>null</td><td>List(2607602309278239)</td><td>0612-074411-zrk0t7cm</td><td>3</td><td>WriteSerializable</td><td>false</td><td>Map(numTargetRowsCopied -> 1, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 2, numTargetBytesAdded -> 2643, numTargetBytesRemoved -> 1328, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatch ...

# %%
# %sql
-- Using version
SELECT * FROM sales VERSION AS OF 0;

-- Using timestamp
SELECT * FROM sales TIMESTAMP AS OF '2025-06-12T07:56:02.000+00:00';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sale_id</th><th>product</th><th>quantity</th><th>sale_date</th></tr></thead><tbody><tr><td>1</td><td>Laptop</td><td>2</td><td>2024-01-01</td></tr><tr><td>2</td><td>Mouse</td><td>10</td><td>2024-01-02</td></tr></tbody></table></div>

# %% [markdown]
# ## **Apply Z-Ordering on a large dataset for optimization.**

# %% [markdown]
# **How to Apply Z-Ordering on a Delta Table in Databricks**
#
# Z-Ordering is a data skipping optimization technique in Delta Lake that clustering data on specific columns — improving query performance, especially with filters.
#
# **When to Use Z-Ordering**
#
# Use Z-Ordering on:
#
# Columns that are frequently used in filters
#
# High-cardinality columns (e.g., user_id, product_id, timestamp)

# %%
# %sql
-- Example Delta table
CREATE TABLE IF NOT EXISTS sales (
  sale_id INT,
  product STRING,
  area STRING,
  quantity INT,
  sale_date DATE
)
USING DELTA;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %python
from pyspark.sql.functions import expr
from pyspark.sql.types import IntegerType
import random

data = [(i, f"Product_{i % 10}", f"Region_{i % 5}", random.randint(1, 10), f"2023-01-{(i % 28) + 1}") for i in range(100000)]
df = spark.createDataFrame(data, ["sale_id", "product", "area", "quantity", "sale_date"])
df.write.format("delta").saveAsTable("sales1")

# %%
# %sql
--Apply Z-Ordering (SQL Cell)
OPTIMIZE sales1
ZORDER BY (area, product);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/sales1</td><td>List(1, 8, List(462480, 462480, 462480.0, 1, 462480), List(58454, 63153, 59524.375, 8, 476195), 0, List(minCubeSize(107374182400), List(0, 0), List(8, 476195), 0, List(8, 476195), 1, null), 1, 8, 0, false, 0, 0, 1749716839364, 1749716850031, 8, 1, null, List(0, 0), 5, 5, 1090)</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE sales1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>sale_id</td><td>bigint</td><td>null</td></tr><tr><td>product</td><td>string</td><td>null</td></tr><tr><td>area</td><td>string</td><td>null</td></tr><tr><td>quantity</td><td>bigint</td><td>null</td></tr><tr><td>sale_date</td><td>string</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM sales1 where area= "Region_1" and product ="Product_6";
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sale_id</th><th>product</th><th>area</th><th>quantity</th><th>sale_date</th></tr></thead><tbody><tr><td>36866</td><td>Product_6</td><td>Region_1</td><td>6</td><td>2023-01-19</td></tr><tr><td>36876</td><td>Product_6</td><td>Region_1</td><td>7</td><td>2023-01-1</td></tr><tr><td>36886</td><td>Product_6</td><td>Region_1</td><td>1</td><td>2023-01-11</td></tr><tr><td>36896</td><td>Product_6</td><td>Region_1</td><td>8</td><td>2023-01